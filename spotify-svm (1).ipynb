# %% [markdown]
# # Data Analysis and Popularity prediction using Support Vector Machine

# %% [markdown]
# Music can be divided into genres (e.g., country music) and genres can be further divided into subgenres (e.g., country blues and pop country are two of the many country subgenres), although the dividing lines and relationships between music genres are often subtle, sometimes open to personal interpretation, and occasionally controversial. For example, it can be hard to draw the line between some early 1980s hard rock and heavy metal. Within the arts, music may be classified as a performing art, a fine art or as an auditory art. Music may be played or sung and heard live at a rock concert or orchestra performance, heard live as part of a dramatic work (a music theater show or opera), or it may be recorded and listened to on a radio, MP3 player, CD player, smartphone or as film score or TV show.
#
# In many cultures, music is an important part of people's way of life, as it plays a key role in religious rituals, rite of passage ceremonies (e.g., graduation and marriage), social activities (e.g., dancing) and cultural activities ranging from amateur karaoke singing to playing in an amateur funk band or singing in a community choir. People may make music as a hobby, like a teen playing cello in a youth orchestra, or work as a professional musician or singer. The music industry includes the individuals who create new songs and musical pieces (such as songwriters and composers), individuals who perform music (which include orchestra, jazz band and rock band musicians, singers and conductors), individuals who record music (music producers and sound engineers), individuals who organize concert tours, and individuals who sell recordings, sheet music, and scores to customers. Even once a song or piece has been performed, music critics, music journalists, and music scholars may assess and evaluate the piece and its performance.

# %% [markdown]
# ![](https://i.pinimg.com/originals/a4/d9/83/a4d983c5fbe14b4c63dd53d93fc2483f.jpg)

# %% [markdown]
# Spotify Technology S.A. is an international media services provider of Swedish origin. It is legally domiciled in Luxembourg and is headquartered in Stockholm, Sweden. Founded in 2006, the company's primary business is providing an audio streaming platform, the "Spotify" platform, that provides DRM-protected music, videos and podcasts from record labels and media companies. As a freemium service, basic features are free with advertisements or automatic music videos, while additional features, such as offline listening and commercial-free listening, are offered via paid subscriptions.
#
# Launched on October 7, 2008, the Spotify platform provides access to over 50 million tracks. Users can browse by parameters such as artist, album, or genre, and can create, edit, and share playlists. Spotify is available in most of Europe and the Americas, Australia, New Zealand, and parts of Africa and Asia, and on most modern devices, including Windows, macOS, and Linux computers, and iOS, and Android smartphones and tablets. As of October 2019, the company had 248 million monthly active users, including 113 million paying subscribers.
#
# Unlike physical or download sales, which pay artists a fixed price per song or album sold, Spotify pays royalties based on the number of artists streams as a proportion of total songs streamed. It distributes approximately 70% of its total revenue to rights holders, who then pay artists based on their individual agreements. Spotify has faced criticism from artists and producers including Taylor Swift and Thom Yorke, who have argued that it does not fairly compensate musicians. In 2017, as part of its efforts to renegotiate license deals for an interest in going public, Spotify announced that artists would be able to make albums temporarily exclusive to paid subscribers if the albums are part of Universal Music Group or the Merlin Network.
#
# Spotify's international headquarters are in Stockholm, Sweden, though each region has its own headquarters. Since February 2018, it has been listed on the New York Stock Exchange and in September 2018, the company relocated its New York City offices to 4 World Trade Center.
# [source](https://en.wikipedia.org/wiki/Spotify "Wikipedia")

# %% [markdown]
# ![](https://images.indianexpress.com/2020/05/spotify-bloom-1200.jpg)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#Data Visualisation
import matplotlib.pyplot as plt
import seaborn as sns

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/top50spotify2019/top50.csv

# %%
from pycaret.regression import *

# %%
data = pd.read_csv("/kaggle/input/top50spotify2019/top50.csv",encoding="ISO-8859-1")

# %%
data.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %%
data.tail()
# Out:
#     Unnamed: 0                                     Track.Name  \
# 45          46                                One Thing Right
# 46          47                                      Te Robaré
# 47          48                                        Happier
# 48          49                                  Call You Mine
# 49          50  Cross Me (feat. Chance the Rapper & PnB Rock)
#
#          Artist.Name    Genre  Beats.Per.Minute  Energy  Danceability  \
# 45        Marshmello  brostep                88      62            66
# 46         Nicky Jam    latin               176      75            67
# 47        Marshmello  brostep               100      79            69
# 48  The Chainsmokers      edm               104      70            59
# 49        Ed Sheeran      pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 45              -2        58        44      182               7             5
# 46              -4         8        80      202              24             6
# 47              -3        17        67      214              19             5
# 48              -6        41        50      218              23             3
# 49              -6         7        61      206              21            12
#
#     Popularity
# 45          88
# 46          88
# 47          88
# 48          88
# 49          82

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %%
data['Genre'].unique()
# Out:
# array(['canadian pop', 'reggaeton flow', 'dance pop', 'pop', 'dfw rap',
#        'trap music', 'country rap', 'electropop', 'reggaeton',
#        'panamanian pop', 'canadian hip hop', 'latin', 'escape room',
#        'pop house', 'australian pop', 'edm', 'atl hip hop', 'big room',
#        'boy band', 'r&b en espanol', 'brostep'], dtype=object)

# %%
#Catplot
#It gives count of genre in spotify top 50 list. 
sns.catplot(y = "Genre", kind = "count",
            palette = "colorblind", edgecolor = ".6",
            data = data)
plt.show()

# %%
plt.figure(figsize=(12,12))
sns.jointplot(x= data["Beats.Per.Minute"].values, y= data['Popularity'].values, size=10, kind="hex",)
plt.ylabel('Popularity', fontsize=12)
plt.xlabel("Beats.Per.Minute", fontsize=12)
plt.title("Beats.Per.Minute Vs Popularity", fontsize=15);
#The purpose of this graph is to show connection among Beats and Popularity

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')

# %%
plt.figure(figsize=(12,12))
sns.jointplot(x= data['Loudness..dB..'].values, y= data['Popularity'].values, size=10, kind="kde",)
plt.ylabel('Popularity', fontsize=12)
plt.xlabel("Beats.Per.Minute", fontsize=12)
plt.title("Beats.Per.Minute Vs Popularity", fontsize=15);
#The purpose of this graph is to show connection among loudness and Popularity

# %%
plt.figure(figsize=(16, 6))
heatmap=sns.heatmap(data.corr(),vmax=1, vmin=-1,annot=True)

# %%
#Pie charts 
labels = data['Artist.Name'].value_counts().index
sizes = data['Artist.Name'].value_counts().values
colors = ['red', 'yellowgreen', 'lightcoral', 'lightskyblue','cyan', 'green', 'black','yellow']
plt.figure(figsize = (10,10))
plt.pie(sizes, labels=labels, colors=colors)
autopct=('%1.1f%%')
plt.axis('equal')
plt.show()

# %%
for i in data['Genre']:
    if "pop" in i:
        data['Genre'] = data['Genre'].replace(i,"pop")
    if "edm" in i:
        data['Genre'] = data['Genre'].replace(i,"edm")
    if "hip hop" in i: 
        data['Genre'] = data['Genre'].replace(i,"hip hop")
    if "room" in i:
        data['Genre'] = data['Genre'].replace(i,"other")
    if "r&b"  in i:  
        data['Genre'] = data['Genre'].replace(i,"other")
    if "reggae" in i:  
        data['Genre'] = data['Genre'].replace(i,"reggae")
    if "rap" in i:
        data['Genre'] = data['Genre'].replace(i,"hip hop")
    if "boy band" in i:
        data['Genre'] = data['Genre'].replace(i,"pop")
    if "brostep" in i:
        data['Genre'] =  data['Genre'].replace(i,"other")

# %%
data['Genre'].unique()
# Out:
# array(['pop', 'reggae', 'hip hop', 'latin', 'other', 'edm'], dtype=object)

# %%
plt.figure(figsize=(16, 6))
data['Genre'].value_counts().plot(kind="bar", color = 'r')

# %%
data.drop(['Track.Name', 'Artist.Name'], axis = 1, inplace = True)
data
# Out:
#     Unnamed: 0    Genre  Beats.Per.Minute  Energy  Danceability  \
# 0            1      pop               117      55            76
# 1            2   reggae               105      81            79
# 2            3      pop               190      80            40
# 3            4      pop                93      65            64
# 4            5  hip hop               150      65            58
# 5            6      pop               102      68            80
# 6            7  hip hop               180      64            75
# 7            8      pop               111      68            48
# 8            9  hip hop               136      62            88
# 9           10      pop               135      43            70
# 10          11   reggae               176      62            61
# 11          12      pop                96      71            82
# 12          13      pop               110      41            50
# 13          14      pop               176      79            73
# 14          15  hip hop               101      50            83
# 15          16      pop                93      45            70
# 16          17    latin               176      65            75
# 17          18  hip hop                90      48            76
# 18          19  hip hop               130      39            84
# 19          20    other               158      62            72
# 20          21      pop               124      74            68
# 21          22  hip hop               154      59            70
# 22          23   reggae                92      79            81
# 23          24    latin                92      78            80
# 24          25      pop               135      45            67
# 25          26      pop               124      82            69
# 26          27      pop                98      59            82
# 27          28  hip hop                96      46            73
# 28          29    latin                94      86            74
# 29          30    latin                93      79            64
# 30          31      edm                85      51            29
# 31          32      pop               140      32            78
# 32          33   reggae                96      71            78
# 33          34  hip hop                98      59            80
# 34          35      pop               100      88            77
# 35          36    other               114      72            66
# 36          37      pop               176      70            75
# 37          38      pop               152      82            72
# 38          39      pop               138      73            84
# 39          40      pop                95      56            81
# 40          41      edm               104      68            69
# 41          42      pop                85      68            77
# 42          43      pop                96      39            57
# 43          44      pop               136      40            90
# 44          45    other                98      69            88
# 45          46    other                88      62            66
# 46          47    latin               176      75            67
# 47          48    other               100      79            69
# 48          49      edm               104      70            59
# 49          50      pop                95      79            75
#
#     Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  Speechiness.  \
# 0               -6         8        75      191               4             3
# 1               -4         8        61      302               8             9
# 2               -4        16        70      186              12            46
# 3               -8         8        55      198              12            19
# 4               -4        11        18      175              45             7
# 5               -5         9        84      220               9             4
# 6               -6         7        23      131               2            29
# 7               -5         8        35      202              15             9
# 8               -6        11        64      157               5            10
# 9              -11        10        56      194              33            38
# 10              -5        24        24      251              60            31
# 11              -4        15        38      185              28             7
# 12              -6        11        45      182              75             3
# 13              -2         6        76      288               7            20
# 14              -4        12        10      205              10             5
# 15              -7        16        14      261              12            15
# 16              -6        11        43      243              15            32
# 17              -6         7        91      158              56             5
# 18              -8        14        50      161              18             8
# 19              -3        12        41      173              11            11
# 20              -7         7        63      153               4             3
# 21              -6        12        48      115              34             8
# 22              -4         9        58      309              14             7
# 23              -4        44        80      266              36             4
# 24             -11        12        68      195              25            30
# 25              -4        13        87      191              49             6
# 26              -6        18        54      210              69            10
# 27              -7        19        40      213              37             3
# 28              -3         6        66      193              11             6
# 29              -4        36        94      222               3            25
# 30              -8        10        36      210              12             4
# 31             -11         9        33      179              59            33
# 32              -5         9        68      176              22            28
# 33              -7        13        18      200               2            15
# 34              -5        32        39      224              19             6
# 35              -7        14        32      164              18             6
# 36              -5        11        62      226              14            34
# 37              -5        36        91      162              13             5
# 38              -5        11        95      181               4             6
# 39              -6         6        68      199              48             7
# 40              -7        10        40      228               2             3
# 41              -6         7        73      171               1             5
# 42              -6        23        32      216              37             3
# 43              -9         6        35      198               5            13
# 44              -4         5        75      162              39            12
# 45              -2        58        44      182               7             5
# 46              -4         8        80      202              24             6
# 47              -3        17        67      214              19             5
# 48              -6        41        50      218              23             3
# 49              -6         7        61      206              21            12
#
#     Popularity
# 0           79
# 1           92
# 2           85
# 3           86
# 4           94
# 5           84
# 6           92
# 7           90
# 8           87
# 9           95
# 10          93
# 11          86
# 12          88
# 13          87
# 14          92
# 15          82
# 16          90
# 17          91
# 18          88
# 19          91
# 20          91
# 21          91
# 22          83
# 23          91
# 24          89
# 25          70
# 26          83
# 27          89
# 28          91
# 29          89
# 30          84
# 31          89
# 32          89
# 33          89
# 34          89
# 35          89
# 36          91
# 37          87
# 38          80
# 39          78
# 40          88
# 41          90
# 42          87
# 43          84
# 44          88
# 45          88
# 46          88
# 47          88
# 48          88
# 49          82

# %%
reg = setup(data = data, 
             target = 'Popularity',
             numeric_imputation = 'mean',
             categorical_features = ['Genre']  , 
             normalize = True,
             silent = True)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_3c204608_dbe2_11ea_97ac_0242ac130202row15_col1 {
#             background-color:  yellow;
#         }</style><table id="T_3c204608_dbe2_11ea_97ac_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row0_col1" class="data row0 col1" >4335</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row1_col0" class="data row1 col0" >Transform Target </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row1_col1" class="data row1 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row2_col0" class="data row2 col0" >Transform Target Method</td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row2_col1" class="data row2 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row3_col0" class="data row3 col0" >Original Data</td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row3_col1" class="data row3 col1" >(50, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row4_col0" class="data row4 col0" >Missing Values </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row4_col1" class="data row4 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row5_col0" class="data row5 col0" >Numeric Features </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row5_col1" class="data row5 col1" >9</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row6_col0" class="data row6 col0" >Categorical Features </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row6_col1" class="data row6 col1" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row7_col0" class="data row7 col0" >Ordinal Features </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row8_col0" class="data row8 col0" >High Cardinality Features </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row9_col0" class="data row9 col0" >High Cardinality Method </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row9_col1" class="data row9 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row10_col0" class="data row10 col0" >Sampled Data</td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row10_col1" class="data row10 col1" >(50, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row11_col1" class="data row11 col1" >(34, 23)</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row12_col1" class="data row12 col1" >(16, 23)</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row13_col0" class="data row13 col0" >Numeric Imputer </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row13_col1" class="data row13 col1" >mean</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row14_col0" class="data row14 col0" >Categorical Imputer </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row14_col1" class="data row14 col1" >constant</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row15_col0" class="data row15 col0" >Normalize </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row15_col1" class="data row15 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row16_col0" class="data row16 col0" >Normalize Method </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row16_col1" class="data row16 col1" >zscore</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row17_col0" class="data row17 col0" >Transformation </td>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_3c204608_dbe2_11ea_97ac_0242ac130202level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_3c204608_dbe2_11ea_97ac_0242ac130202row18_col0" class="data row18 col0" >Transformation Method </td>
#                         <td id

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_50e74adc_dbe2_11ea_97ac_0242ac130202 th {
#           text-align: left;
#     }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row0_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row0_col2 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row0_col3 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row0_col6 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row0_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row1_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row1_col1 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row1_col2 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row1_col3 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row1_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row1_col5 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row1_col6 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row1_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row2_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row2_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row2_col2 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row2_col3 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row2_col4 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row2_col5 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row2_col6 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row2_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row3_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row3_col1 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row3_col2 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row3_col3 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row3_col4 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row3_col5 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row3_col6 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row3_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row4_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row4_col1 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row4_col2 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row4_col3 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row4_col4 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row4_col5 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row4_col6 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row4_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row5_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row5_col1 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row5_col2 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row5_col3 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row5_col4 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row5_col5 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row5_col6 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row5_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row6_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row6_col1 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row6_col2 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row6_col3 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row6_col4 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row6_col5 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row6_col6 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row6_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row7_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row7_col1 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row7_col2 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row7_col3 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row7_col4 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row7_col5 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row7_col6 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row7_col7 {
#             background-color:  lightgrey;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row8_col0 {
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row8_col1 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row8_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row8_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_0242ac130202row8_col4 {
#             : ;
#             text-align:  left;
#         }    #T_50e74adc_dbe2_11ea_97ac_
# LassoLars(alpha=1.0, copy_X=True, eps=2.220446049250313e-16, fit_intercept=True,
#           fit_path=True, jitter=None, max_iter=500, normalize=True,
#           positive=False, precompute='auto', random_state=None, verbose=False)

# %%
svm = create_model('svm')
# Out:
# <style  type="text/css" >
#     #T_513e14ca_dbe2_11ea_97ac_0242ac130202row10_col0 {
#             background:  yellow;
#         }    #T_513e14ca_dbe2_11ea_97ac_0242ac130202row10_col1 {
#             background:  yellow;
#         }    #T_513e14ca_dbe2_11ea_97ac_0242ac130202row10_col2 {
#             background:  yellow;
#         }    #T_513e14ca_dbe2_11ea_97ac_0242ac130202row10_col3 {
#             background:  yellow;
#         }    #T_513e14ca_dbe2_11ea_97ac_0242ac130202row10_col4 {
#             background:  yellow;
#         }    #T_513e14ca_dbe2_11ea_97ac_0242ac130202row10_col5 {
#             background:  yellow;
#         }</style><table id="T_513e14ca_dbe2_11ea_97ac_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_513e14ca_dbe2_11ea_97ac_0242ac130202level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row0_col0" class="data row0 col0" >3.3816</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row0_col1" class="data row0 col1" >16.8792</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row0_col2" class="data row0 col2" >4.1084</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row0_col3" class="data row0 col3" >0.1203</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row0_col4" class="data row0 col4" >0.0455</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row0_col5" class="data row0 col5" >0.0378</td>
#             </tr>
#             <tr>
#                         <th id="T_513e14ca_dbe2_11ea_97ac_0242ac130202level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row1_col0" class="data row1 col0" >1.7947</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row1_col1" class="data row1 col1" >5.1106</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row1_col2" class="data row1 col2" >2.2607</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row1_col3" class="data row1 col3" >-0.1357</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row1_col4" class="data row1 col4" >0.0250</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row1_col5" class="data row1 col5" >0.0200</td>
#             </tr>
#             <tr>
#                         <th id="T_513e14ca_dbe2_11ea_97ac_0242ac130202level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row2_col0" class="data row2 col0" >3.6550</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row2_col1" class="data row2 col1" >21.9246</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row2_col2" class="data row2 col2" >4.6824</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row2_col3" class="data row2 col3" >0.0336</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row2_col4" class="data row2 col4" >0.0541</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row2_col5" class="data row2 col5" >0.0430</td>
#             </tr>
#             <tr>
#                         <th id="T_513e14ca_dbe2_11ea_97ac_0242ac130202level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row3_col0" class="data row3 col0" >6.7476</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row3_col1" class="data row3 col1" >92.5234</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row3_col2" class="data row3 col2" >9.6189</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row3_col3" class="data row3 col3" >-0.4303</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row3_col4" class="data row3 col4" >0.1196</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row3_col5" class="data row3 col5" >0.0909</td>
#             </tr>
#             <tr>
#                         <th id="T_513e14ca_dbe2_11ea_97ac_0242ac130202level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row4_col0" class="data row4 col0" >2.6273</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row4_col1" class="data row4 col1" >8.0341</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row4_col2" class="data row4 col2" >2.8345</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row4_col3" class="data row4 col3" >-0.9028</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row4_col4" class="data row4 col4" >0.0320</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row4_col5" class="data row4 col5" >0.0302</td>
#             </tr>
#             <tr>
#                         <th id="T_513e14ca_dbe2_11ea_97ac_0242ac130202level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row5_col0" class="data row5 col0" >0.6661</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row5_col1" class="data row5 col1" >0.4989</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row5_col2" class="data row5 col2" >0.7063</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row5_col3" class="data row5 col3" >-1.2452</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row5_col4" class="data row5 col4" >0.0080</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row5_col5" class="data row5 col5" >0.0076</td>
#             </tr>
#             <tr>
#                         <th id="T_513e14ca_dbe2_11ea_97ac_0242ac130202level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row6_col0" class="data row6 col0" >2.2237</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row6_col1" class="data row6 col1" >9.7127</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row6_col2" class="data row6 col2" >3.1165</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row6_col3" class="data row6 col3" >-0.4099</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row6_col4" class="data row6 col4" >0.0338</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row6_col5" class="data row6 col5" >0.0239</td>
#             </tr>
#             <tr>
#                         <th id="T_513e14ca_dbe2_11ea_97ac_0242ac130202level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row7_col0" class="data row7 col0" >2.3014</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row7_col1" class="data row7 col1" >8.2336</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row7_col2" class="data row7 col2" >2.8694</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row7_col3" class="data row7 col3" >-0.9501</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row7_col4" class="data row7 col4" >0.0328</td>
#                         <td id="T_513e14ca_dbe2_11ea_97ac_0242ac130202row7_col5" class="data row7 col5" >0.0271</td>
#             </tr>
#             <tr>

# %% [markdown]
# # Residuals for SVR Model

# %%
plot_model(svm)

# %% [markdown]
# ![](![svm.png](attachment:svm.png))

# %% [markdown]
# # Prediction error for SVR

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# # Cook's distance outlier detection

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# # Learning Curve for SVR

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# ![](http://)

# %% [markdown]
# # Validation Curve for SVR

# %% [markdown]
# ![](data:image/png;base64,...)

# %% [markdown]
# # Manifold Learning plot

# %% [markdown]
# ![](data:image/png;base64,...)
